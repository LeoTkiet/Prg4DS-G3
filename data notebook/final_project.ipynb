# %% [markdown]
# # 1. Collecting data

# %% [markdown]
# # 2. Exploring data

# %% [markdown]
# # 3. Asking meaningful questions

# %% [markdown]
# # 4. Preprocessing + analyzing data

# %% [markdown]
# # 5. Reflection

# %% [markdown]
# # 6. References
